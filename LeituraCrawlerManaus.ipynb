# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagossilva11/Spotify-Machine-Learning-Project/blob/main/LeituraCrawlerManaus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import psycopg2

# %%
con = psycopg2.connect(host='34.23.173.147',
                       database='SGM',
                       user='terralab',
                       password='terralab0705')
cur = con.cursor()

# %%
cur.execute('select res.geoapi_id, req.request_id, res.latitude, res.longitude, res.accuracy, req.number, req.district, req.public_place from "Response" as res join "Request" as req on res.request_id = req.request_id where req.request_id >= 3700832 and req.request_id <= 3701831')
recset = cur.fetchall()

# %%
import pandas as pd
geo = pd.DataFrame(recset, columns = ['geoapi_id', 'request_id', 'lat', 'long', 'accuracy', 'number', 'district', 'public_place'])

# %%
geo = geo.sort_values(by='request_id')
geo = geo.reset_index(drop=True)
geo.head()
# Out:
#           geoapi_id  request_id        lat       long   accuracy number  \
# 0            MapBox     3700832 -12.849080 -38.387868   0.606173      0
# 1            TomTom     3700832 -12.838950 -38.379500   9.685124      0
# 2            Google     3700832 -12.849265 -38.388449        NaN      0
# 3  OpenRouteService     3700832 -12.964413 -38.421936   0.600000      0
# 4            TomTom     3700833 -12.919630 -38.374250  13.206676      0
#
#   district         public_place
# 0           SERRA DA CANTAREIRA
# 1           SERRA DA CANTAREIRA
# 2           SERRA DA CANTAREIRA
# 3           SERRA DA CANTAREIRA
# 4                     9 SETOR F

# %%
geo.to_csv('geo.csv')

# %%
geo["geoapi_id"].unique()
# Out:
# array(['MapBox', 'TomTom', 'Google', 'OpenRouteService'], dtype=object)

# %%
import pandas as pd

# %%
amostra = pd.read_csv("/content/amostraMil.csv")
padronizado = pd.read_csv("/content/manausInteiro.csv")
amostra_lat_long = padronizado[["LATITUDE", "LONGITUDE"]]
original = padronizado.copy()

# Adicionar as colunas "LATITUDE" e "LONGITUDE" do dataframe "amostra" ao dataframe "original"
original[["latGold","lonGold"]] = amostra_lat_long
if 'Unnamed: 0' in original.columns:
    original.drop('Unnamed: 0', axis=1, inplace=True)


original['id'] = range(3702270, 3702270 + len(original))
original.head()
# Out:
#   NOM_TIPO_SEGLOGR NOM_TITULO_SEGLOGR       NOM_SEGLOGR  NUM_ENDERECO  \
# 0              RUA                NAN           TAPAJOS            97
# 1              RUA                NAN  SETE DE SETEMBRO            53
# 2              RUA                NAN  EDSON VIEIRALVES             3
# 3              RUA                NAN       CARLOS DIAS            65
# 4             BECO                SAO           VICENTE            14
#
#         CEP MUNICIPIO  UF  LONGITUDE  LATITUDE   latGold    lonGold       id
# 0  69008100    MANAUS  AM -59.888995 -3.085914 -3.085914 -59.888995  3702270
# 1  69019434    MANAUS  AM -59.924920 -3.026120 -3.026120 -59.924920  3702271
# 2  69098269    MANAUS  AM -59.957292 -3.051137 -3.051137 -59.957292  3702272
# 3  69073185    MANAUS  AM -59.988086 -3.128633 -3.128633 -59.988086  3702273
# 4  69035641    MANAUS  AM -60.062941 -3.099458 -3.099458 -60.062941  3702274

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
geo = pd.read_csv("/content/geo.csv")
geo.head()
# Out:
#    Unnamed: 0 geoapi_id  request_id        lat       long   accuracy  number  \
# 0           0    MapBox     3700832 -12.849080 -38.387868   0.606173       0
# 1           1    TomTom     3700832 -12.838950 -38.379500   9.685124       0
# 2           2    TomTom     3700833 -12.919630 -38.374250  13.206676       0
# 3           3    MapBox     3700833 -12.911071 -38.367600   0.709599       0
# 4           4    TomTom     3700834 -12.951500 -38.490980  13.265202      18
#
#    district         public_place
# 0       NaN  SERRA DA CANTAREIRA
# 1       NaN  SERRA DA CANTAREIRA
# 2       NaN            9 SETOR F
# 3       NaN            9 SETOR F
# 4       NaN    1 TRAVESSA BOMFIM

# %%
#Junção dos dados geocodificados com os dados ouro#

# %%
result_df = original.merge(geo, how='inner', left_on='id', right_on='request_id')
result_df.head(50)
# Out:
# Empty DataFrame
# Columns: [NOM_TIPO_SEGLOGR, NOM_TITULO_SEGLOGR, NOM_SEGLOGR, NUM_ENDERECO, CEP, MUNICIPIO, UF, LONGITUDE, LATITUDE, latGold, lonGold, id, Unnamed: 0, geoapi_id, request_id, lat, long, accuracy, number, district, public_place]
# Index: []
#
# [0 rows x 21 columns]

# %%
aux = result_df.drop_duplicates(subset=['request_id', 'geoapi_id'])

# %%
result_df = aux

# %%
result_df.to_csv('result_df.csv')

# %%
geo['geoapi_id'].unique().tolist()
# Out:
# ['MapBox', 'TomTom']
